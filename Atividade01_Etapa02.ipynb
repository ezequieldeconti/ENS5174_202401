# %% [markdown]
# Etapa 02 - 07/04/24

# %% [markdown]
# 1.1 Numpy arrays

# %%
import numpy as np #importa a numpy chamando de np

# Criando um vetor de dados aleatórios
data = np.random.rand(1000,2) #está criando um vetor chamado data cm valores aleatórios de 1000 linhas e 2 colunas

# Verificando o tamanho do vetor
print(data.shape) #mostra as dimensões do vetor data
print(np.size(data)) #mostra a quantidade de células do vetor

# Print de uma amostra dos dados
print(data[0:10])
print(data[0:10].shape)
# Out:
# (1000, 2)
# 2000
# [[0.35799691 0.99806132]
#  [0.49440997 0.9608012 ]
#  [0.52612827 0.82076178]
#  [0.07263742 0.00964926]
#  [0.94992163 0.88519803]
#  [0.33600894 0.61767963]
#  [0.35912243 0.96210223]
#  [0.12043125 0.35279783]
#  [0.38283456 0.84459541]
#  [0.51480027 0.85740481]]
# (10, 2)

# %%
# Usando Monte-Carlo

dataMax = 1000 # Cria uma variavel com valor 1000 (max)
dataMin = 10 # Cria a variavel com valor 10 (min)
data = (dataMax - dataMin)*data + dataMin 
print(data[0:10])
# Out:
# [[4.00244836e+20 7.03964521e+20]
#  [2.83803632e+20 2.21710037e+20]
#  [3.52868194e+20 2.55201447e+20]
#  [5.29364064e+20 2.90363246e+20]
#  [6.52107749e+20 2.69643766e+20]
#  [8.63925714e+19 1.10556581e+20]
#  [7.37838816e+20 6.67341037e+20]
#  [7.66035896e+20 4.81263954e+20]
#  [2.88942956e+20 9.31303825e+20]
#  [5.64487590e+20 3.50513252e+20]]

# %%
import matplotlib.pyplot as plt #importa uma determinada coleção de funções do matplotlib chamando de plt

fig,ax = plt.subplots(3) #cria 3 subplots e um conjunto de eixos (ax) com a finalidade de fazer gráficos
ax[0].plot(data) 
ax[1].plot(data[:,0])
ax[2].plot(data[:,1])
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
# Criando um dado 2D 
data3d = np.sin(np.random.rand(1000,1000))
print(data3d)
# Out:
# [[0.64645323 0.13098974 0.7669916  ... 0.46182392 0.60748637 0.31134014]
#  [0.67574818 0.01124074 0.25805133 ... 0.36935578 0.13008162 0.15540233]
#  [0.70686282 0.32546279 0.01785493 ... 0.7457017  0.01695399 0.54076993]
#  ...
#  [0.56397356 0.48820734 0.77733172 ... 0.57579973 0.74673415 0.0031653 ]
#  [0.33318956 0.71614984 0.12948765 ... 0.5863265  0.72986611 0.59701928]
#  [0.74697105 0.47781688 0.69381904 ... 0.36599309 0.48755362 0.21640624]]

# %%
# Criando um dado 2D
data3d = np.sin(np.random.rand(1000,1000)) #vai criar uma matriz (data3d) de dimensões 1000x1000 

# Plotando um dado 3D
fig2, ax2 = plt.subplots() 
ax2.pcolor(data3d) #plota a matriz
# Out:
# [[0.50677315 0.44540971 0.7883558  ... 0.32614738 0.50637355 0.42254853]
#  [0.02270326 0.2078305  0.40243385 ... 0.23112063 0.47463888 0.39343698]
#  [0.81165708 0.64662663 0.42801915 ... 0.63470071 0.37873677 0.51321893]
#  ...
#  [0.77796269 0.73413643 0.46776508 ... 0.46992116 0.78354203 0.27642234]
#  [0.45289132 0.8398205  0.64372075 ... 0.17508487 0.56720967 0.64642669]
#  [0.2466727  0.65931957 0.13614543 ... 0.81248261 0.0178301  0.44466101]]

# %%
# Criando vertor temporal
import numpy as np

# Criando um array de datas e tempos
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1, "h")) #cria dados que vao entre 2022 e 2023
print(dtime[1:10])
print(dtime.shape)
print(type(dtime))
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %% [markdown]
# PANDAS

# %%
import pandas as pd

# Criando um dataframe
df = pd.DataFrame()
# Monstrando um dataframe
df['datetime'] = dtime
# Criando uma coluna random dentro do dataframe df
df['random'] = np.random.rand(df.shape[0])
df['random'][1:10]
# Indexação
df.iloc[:,0]
# Out:
# 0      2022-01-01 00:00:00
# 1      2022-01-01 01:00:00
# 2      2022-01-01 02:00:00
# 3      2022-01-01 03:00:00
# 4      2022-01-01 04:00:00
#                ...
# 8755   2022-12-31 19:00:00
# 8756   2022-12-31 20:00:00
# 8757   2022-12-31 21:00:00
# 8758   2022-12-31 22:00:00
# 8759   2022-12-31 23:00:00
# Name: datetime, Length: 8760, dtype: datetime64[s]

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime'])
df
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.032103
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.776217
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.768611
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.697899
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.318715
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.734670
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.338849
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.175124
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.447579
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.808159
#
# [8760 rows x 2 columns]

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
tt = np.arange(0,df.shape[0],1)
print(tt.shape)
df['sazonal'] = (np.cos(tt/(360*4)))
df['timeSeries'] = 10*df['sazonal']+df['random']
#df['sazonal'].plot()
df['timeSeries'].plot(color='red')
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
df #é o dataframe com os dados de coluna e linhas usado no gráfico acima
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.032103  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.776217  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.768611  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.697899  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.318715  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.734670  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.338849  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.175124  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.447579  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.808159  2022     12   31  0.979958
#
# ...

# %%
# Salvar meu dataframe

df.to_csv(r'C:\Users\admin\Documents\ENS5174_202401\dados\brutos\noise_2022.csv') #salvei o dataframe no meu diretório

# %%
# Criando uma função
def noiseCreation(path,year): # Cria a função noiseCreation com entradas: path e year
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas

    Criado por Ezequiel
    """

    # Criando um dataframe
    df = pd.DataFrame() 

    # Criando vertor temporal
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h"))
   
    # Montando um dataframe
    df['datetime'] = dtime 

    # Datetime como index do dataframe
    df = df.set_index(df['datetime']) 
    
    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year 
    df['month'] = df.index.month 
    df['day'] = df.index.day

    # Crio uma coluna random
    df['random'] = np.random.rand(df.shape[0]) # Cria uma coluna no dataframe df chamada random com valores de 0 a 1, e com o número de linhas da primeira coluna do dataframe df

    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1) 
    print(tt.shape) 
    df['sazonal'] = (np.cos(tt/(360*4))) 
    df['timeSeries'] = 10*df['sazonal']+df['random'] 
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red') 
    df.to_csv(path+'noise_'+str(year)+'.csv') 

    return df #retorna o dataframe df criado

# %%
path = 'C:/Users/admin/Documents/ENS5174_202401/dados/brutos/' #diretório definido para 'path'
df2 = noiseCreation(path,2050)
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010): #estrtura de repetição for 
    print(ii)
    df = noiseCreation(path,ii) #cria o df
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %%
df
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.615649  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.132813  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.856969  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.670431  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.157603  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.183292  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.607153  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.836374  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.040931  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.409186  0.979958
#
# ...

# %%
anos = [2001,2030,2032,2053,2060] #cria uma lista com esses valores

for ano in anos: #estrtura de repetição for
    print(ano)
    if ano > 2030: #cria uma condição com if
        df = noiseCreation(path,ano) #cria um df
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %%
import os #importou da biblioteca o files
files = os.listdir(path) 
print(files)

allData = []
for file in files: 
    if file.endswith('.csv'):
        print(file)
        data = pd.read_csv(path+'/'+file)
        allData.append(data)
# Out:
# ['noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2022.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv']
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2022.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %%
allDataDf = pd.concat(allData) #criado pelo pandas

allDataDf #mostra o allDataDf
# Out:
#                  datetime           datetime.1  year  month  day    random  \
# 0     2002-01-01 00:00:00  2002-01-01 00:00:00  2002      1    1  0.258470
# 1     2002-01-01 01:00:00  2002-01-01 01:00:00  2002      1    1  0.575577
# 2     2002-01-01 02:00:00  2002-01-01 02:00:00  2002      1    1  0.510213
# 3     2002-01-01 03:00:00  2002-01-01 03:00:00  2002      1    1  0.285840
# 4     2002-01-01 04:00:00  2002-01-01 04:00:00  2002      1    1  0.037655
# ...                   ...                  ...   ...    ...  ...       ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  2060     12   31  0.231824
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  2060     12   31  0.040570
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  2060     12   31  0.224895
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  2060     12   31  0.993915
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  2060     12   31  0.024988
#
#        sazonal  timeSeries
# 0     1.000000   10.258470
# ...

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries']) #plota o 'datetime' no eixo x e 'timeSeries' no eixo y
